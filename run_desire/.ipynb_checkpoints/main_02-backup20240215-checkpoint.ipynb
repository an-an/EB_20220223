# %% [markdown]
# <span style="font-size: 400%; color: black;">E & B: DeSIRe inversion</span>
#
# + Directory: tanan_dkist_ocp01_feb_04
# + Data:    OCP1.2, February
# + Profile: Strong NCP
# + Taking into account stray light for Ca II H, with assuming that DeSIRe cannot reproduce CaIIH wings, even if there is no stray light.
#   I am thinking to modify the profile anyway so that it fits with models to go ahead. Arrowing negative stray light. How data is normalized? Can DeSIRe fit atlas profile?
# + copy from tanan_dkist_ocp01_feb_03/main_02.ipynb
#
# + AI:
#     + No stray light, main_02.ipynb will take into account the stray light
#     + Response function, asking Carlos
#     + Inversion error

# %% [markdown]
# # Check environments

# %%
#!python --version
import sys
print(sys.executable)
# Out:
# /opt/anaconda/bin/python

# %%
import sys
import pprint
pprint.pprint(sys.path)
# Out:
# ['/home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04',
#  '/opt/anaconda/lib/python37.zip',
#  '/opt/anaconda/lib/python3.7',
#  '/opt/anaconda/lib/python3.7/lib-dynload',
#  '',
#  '/home/tanan/.local/lib/python3.7/site-packages',
#  '/opt/anaconda/lib/python3.7/site-packages',
#  '/opt/anaconda/lib/python3.7/site-packages/IPython/extensions',
#  '/home/tanan/.ipython']

# %% [markdown]
# # Import

# %%
import numpy as np               # Needed to perform most of the mathemitcal operations
import matplotlib.pyplot as plt  # We will use it for plotting
from readwrite import readmod    # Needed for reading atmospheres in SIR/DeSIRe format
from readwrite import writemod   # Needed for writing atmospheres in SIR/DeSIRe format
from readwrite import readprof   # Needed for reading profiles in SIR/DeSIRe format
from readwrite import writeprof  # Needed for writing profiles in SIR/DeSIRe format
from readwrite import readrf     # Needed for reading Response Functions in SIR/DeSIRe
import sys                       # We can use it for exiting a program at any time
import os                        # This will allow us to run Linux commands from Python
import shutil

# %% [markdown]
# # Variables

# %%
dir0   = '/home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/'
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/ncp_x026_y030.txt'
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x027_y030.txt'  # looks best around (26,30), cannot fit FiV
infile = '/data/tanan/idl/20230507_1_make_data_03/07/x025_y030.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x024_y030.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x028_y030.txt'  # ?
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x029_y030.txt'  # can fit FeI V

#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x024_y031.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x025_y031.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x026_y031.txt'  # cannot fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x027_y031.txt'  # cannot fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x028_y031.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x029_y031.txt'  # can fit FeI V

#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x024_y029.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x025_y029.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x026_y029.txt'  # cannot fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x027_y029.txt'  # cannot fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x028_y029.txt'  # can fit FeI V
#infile = '/data/tanan/idl/20230507_1_make_data_03/07/x029_y029.txt'  # can fit FeI V

outpngfilehead = dir0 + 'tanan_dkist_ocp01_feb_04_main_02_initatmos_'

id_grid= ['1','23,24','4']
ncycle = 2   # 4 doesn't change much
hxy    = [-720., 310.]

stray_level = [0.15, 0., 0.]

# take over from tanan_dkist_ocp01_feb_03
mag    = np.array([0.25, 1.00, 1.0])
offset = np.array([0.015, 0.00, 0.0])

# %%
file_atmos = dir0 + 'input/atmos.mod'
file_lines = dir0 + 'input/LINES_NLTE'
file_wave  = dir0 + 'input/wave.grid'
file_abund = dir0 + 'input/ASPLUND'
file_ctrl  = dir0 + 'desire.dtrol'
file_obs   = dir0 + 'input/profiles.per'
file_obs0   = dir0 + 'input/profiles0.per'
file_pos   = dir0 + 'input/pos.coor'
file_rfctrl= dir0 + 'rf.dtrol'
file_stray = dir0 + 'input/stray.per'

file_outmod= (file_atmos.split('.mod'))[0]+'_{:1.0f}'.format(ncycle)+'.mod'
file_outpro= (file_atmos.split('.mod'))[0]+'_{:1.0f}'.format(ncycle)+'.per'

file_takeover_txt = dir0 + 'takeover.txt'
file_takeover_npz = dir0 + 'takeover.npz'

id = np.zeros((len(id_grid)), dtype=float)
for i in range(0,len(id_grid)):
    id[i]=float((id_grid[i].split(','))[0])

# %%
# Make take over files
np.savez(file_takeover_npz, mag=mag, offset=offset) 

f = open(file_takeover_txt, 'w')
f.write(infile+'\n') 
f.write(file_outmod+'\n') 
f.close()

print(file_takeover_npz)
print(file_takeover_txt)
# Out:
# /home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/takeover.npz
# /home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/takeover.txt

# %% [markdown]
# # Read profile txt

# %%
f = open(infile, 'r')
for iline in range(0,3):
    nwave  = int(f.readline())
    wave   = np.zeros((nwave), dtype = float)
    stki   = np.zeros((nwave), dtype = float)
    stkq   = np.zeros((nwave), dtype = float)
    stku   = np.zeros((nwave), dtype = float)
    stkv   = np.zeros((nwave), dtype = float)
    for iwave in range(0,nwave):
        txt = f.readline()
        txt1= (txt.split('\n'))[0]
        txt2= txt1.split(' ')
        txt3= [''] * 5 
        ipol = 0
        for i in range(0,len(txt2)):
            if txt2[i] != '':
                txt3[ipol] = float(txt2[i])
                ipol=ipol+1
        wave[iwave] = float(txt3[0])
        stki[iwave] = float(txt3[1])
        stkq[iwave] = float(txt3[2])
        stku[iwave] = float(txt3[3])
        stkv[iwave] = float(txt3[4])

    if iline == 0:
        wave_397 = wave
        stki_397 = stki
        stkq_397 = stkq
        stku_397 = stku
        stkv_397 = stkv
    if iline == 1:
        wave_630 = wave
        stki_630 = stki
        stkq_630 = stkq
        stku_630 = stku
        stkv_630 = stkv
    if iline == 2:
        wave_854 = wave
        stki_854 = stki
        stkq_854 = stkq
        stku_854 = stku
        stkv_854 = stkv

f.close
# Out:
# <function TextIOWrapper.close()>

# %%
print('Observed profile')
fig, ax = plt.subplots(nrows=12, ncols=1, figsize = (8,20), dpi=80)
#fig.suptitle('Observed profile', fontsize=16)
ax = ax.flatten()
for iline in range(0,3):
    if iline == 0:
        wavename = 'Ca II H & H epsilon'
        wave = wave_397
        stki = stki_397
        stkq = stkq_397
        stku = stku_397
        stkv = stkv_397
    if iline == 1:
        wavename = 'Fe I 630 nm'
        wave = wave_630
        stki = stki_630
        stkq = stkq_630
        stku = stku_630
        stkv = stkv_630
    if iline == 2:
        wavename = 'Ca II 854 nm'
        wave = wave_854
        stki = stki_854
        stkq = stkq_854
        stku = stku_854
        stkv = stkv_854

    for ipol in range(0,4):
        if ipol == 0:
            title = wavename+', Stokes I'
            stk = stki
        if ipol == 1:
            title = wavename+', Stokes Q'
            stk = stkq
        if ipol == 2:
            title = wavename+', Stokes U'
            stk = stku
        if ipol == 3:
            title = wavename+', Stokes V'
            stk = stkv #/stki
            
        i = iline*4 + ipol
        ax[i].plot(wave,stk, marker='+', color='black', linewidth=3, linestyle=' ', alpha=1, label='YES')
        ax[i].set_title(title)
        #ax[i].set_ylim(-0.003,0.003)

fig.tight_layout()
# Out:
# Observed profile

# %% [markdown]
# # Input

# %% [markdown]
# ## Input: Atmosphere

# %% [markdown]
# ### Input: Atmosphere: Read

# %%
# read
#initial_atmos = '/home/tanan/lib/desire/DeSIRe_tutorials/Tutorial1/HSRA.mod'
initial_atmos = '/home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/fe630.mod'

atm0,atm1 = readmod(initial_atmos)
print('------------------------------------------')
print('Atmosphere header info =',atm0.shape)
print('Atmosphere columns info =',atm1.shape)
print('')
# Out:
# ------------------------------------------
# Atmosphere header info = (3,)
# Atmosphere columns info = (95, 11)

# %% [markdown]
# ### Input: Atmosphere: Modify and write

# %%
pos = (np.where( (atm1[:,0] > -2.5) & (atm1[:,0] < -1.5) ))[0]   # Change Fe I
pos = (np.where( (atm1[:,0] > -3.5) & (atm1[:,0] < -2.5) ))[0]   # Change Ca II H wings, Ca II 854 up
pos = (np.where( (atm1[:,0] > -4.5) & (atm1[:,0] < -4.0) ))[0]   # Change Ca II H2 little Up, no change Ca II 854 
pos = (np.where( (atm1[:,0] > -4.0) & (atm1[:,0] < -3.5) ))[0]   # Change Ca II H12 Up, no change Ca II 854 
pos = (np.where( (atm1[:,0] > -5.0) & (atm1[:,0] < -4.5) ))[0]   # No Ca II H2, Ca II 854 core up 
pos = (np.where( (atm1[:,0] > -5.5) & (atm1[:,0] < -5.0) ))[0]   # No Ca II H2, no Ca II 854 core 

pos = (np.where( (atm1[:,0] > -4.0) & (atm1[:,0] < -3.5) ))[0]   # Change Ca II H12 Up, no change Ca II 854 
atm1[pos,1] = atm1[pos,1]+1e3

pos = (np.where( (atm1[:,0] > -2.5) & (atm1[:,0] < -1.5) ))[0]   # Change Fe I
pos = (np.where( (atm1[:,0] > -3.5) & (atm1[:,0] < -2.5) ))[0]   # NO Ca II H wings, change strange Ca II 854 
pos = (np.where( (atm1[:,0] > -4.5) & (atm1[:,0] < -4.0) ))[0]   # Change Ca II H
pos = (np.where( (atm1[:,0] > -4.0) & (atm1[:,0] < -3.5) ))[0]   # Change Ca II 854
pos = (np.where( (atm1[:,0] > -5.0) & (atm1[:,0] < -4.5) ))[0]   # Ca II H core, Ca II 854 core wide good 
pos = (np.where( (atm1[:,0] > -5.5) & (atm1[:,0] < -5.0) ))[0]   # Ca II H core little, no Ca II 854 core 

pos = (np.where( (atm1[:,0] > -5.0) & (atm1[:,0] < -4.5) ))[0]   # Ca II H core, Ca II 854 core wide good 
atm1[pos,3] = atm1[pos,3]+5e5

# Magnetic field strength
pos = (np.where(atm1[:,0] < -2))[0]
atm1[pos,4] = (atm1[pos,0] + 2.) * (200.) + atm1[pos[0],4]






# Modify and write
#atm0[0]   = atm0[0]*0.+0.001    # Macroturbulence            [km/s]
#atm1[:,3] = atm1[:,3]*0.+1e5  # Microturbulence            [cm/s]
#atm1[:,4] = atm1[:,4]*0.+200.   # Magnetic field strength    [G]
#atm1[:,5] = atm1[:,5]*0.-1e5    # LOS velocity               [cm/s]
#atm1[:,6] = atm1[:,6]*0.+45.    # Magnetic field inclination [degrees]
#atm1[:,7] = atm1[:,7]*0.+20.    # Magnetic field azimuth     [degrees]


# broaden Ca H and 854, but Fe I
#pos = (np.where(atm1[:,0] < -1.5))[0]
#atm1[pos,3] = 5e5

# brighten CaH2
#pos = (np.where(atm1[:,0] < -4.))[0]
#pos = (np.where((atm1[:,0] < -3.5) & (atm1[:,0] > -5.)))[0]

#atm1[pos,1] = atm1[pos,1]+1e3  # Temperature
#atm1[pos,3] = 10e5

# LOS velocity
#atm1[:,5] = atm1[:,0]*(3e4) - 1e5    # LOS velocity               [cm/s]
# LOS velocity               [cm/s]
#atm1[:,5] = atm1[:,0] * (0.5e5)
pos = (np.where(atm1[:,0] < -3))[0]
atm1[pos,5] = (atm1[pos,0] + 3.) * (-5e5) + atm1[pos[0],5] - 10e5

# corona
#pos = (np.where(atm1[:,0] < -5.5))[0]
#atm1[pos,1] = atm1[pos,1]+2e3  # Temperature











# Good for CaII854 I, but CaIIH I
#pos = (np.where(atm1[:,0] < -3.0))[0]
#atm1[pos,1] = atm1[pos,1]+1e3

#pos = (np.where((atm1[:,0] < -3.0) & (atm1[:,0] > -4.5)))[0]
#atm1[pos,1] = atm1[pos,1]+1e3

#atm1[:,4] = atm1[:,4]*0.+ atm1[:,0]*(-100.)   # Magnetic field strength    [G]


writemod(atm0,atm1,file_atmos)
atm0,atm1 = readmod(file_atmos)

# %% [markdown]
# ### Input: Atmosphere: Plot

# %%
print('Macroturbulence [km/s]: ', atm0[0])
print('Filling factor        : ', atm0[1])
print('Stray light           : ', atm0[2])
# Out:
# Macroturbulence [km/s]:  1.04301
# Filling factor        :  1.0
# Stray light           :  0.0

# %%
fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,1])
axs.set(ylabel='Temperature [K]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_01.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,2])
axs.set(ylabel='Electron Pressure [dyn/cm2]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_02.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,3]*1e-5)
axs.set(ylabel='Microturbulence [km/s]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_03.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,4])
axs.set(ylabel='Magnetic field strength [G]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_04.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,5]*1e-5)
axs.set(ylabel='LOS velocity [km/s]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_05.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,6])
axs.set(ylabel='Magnetic field inclination [degrees]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_06.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,7])
axs.set(ylabel='Magnetic field azimuth [degrees]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_07.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,8])
axs.set(ylabel='Geometrical height [km]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_08.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,9])
axs.set(ylabel='Gas pressure [dyn/cm2]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_09.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,10])
axs.set(ylabel='Gas density [cm-3]',xlabel='log '+r'$\tau_{500}$')
plt.show()
fig.savefig(outpngfilehead+'_10.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)


# fig.savefig('Temperature_HSRA.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)
# fig.savefig('Temperature_HSRA.eps',dpi=300, bbox_inches = 'tight', pad_inches = 0.01)
# sys.exit()

# %% [markdown]
# ## Input: LINES

# %% [markdown]
# + Should we write for each fine structure of H epsilon
# + What is the enhancement corrections due to collisions with neutral H for H epsilon?
# + Can we use the same number of the atomic levels that generate the transition of interest?

# %%
f = open(file_lines, 'r')
txt = f.readlines()
f.close()

for iline in range(0,len(txt)):
    txt0 = txt[iline]
    txt1 = (txt0.split('\n'))[0]
    txt2 = txt1.split(' ')

    j=0
    for i in range(0,len(txt2)):
        if txt2[i] != '':
            j=j+1
            if j == 3: 
                if iline == 0:
                    wvl_cen = [float(txt2[i])]
                else:
                    wvl_cen = np.concatenate((wvl_cen, [float(txt2[i])]))

# %% [markdown]
# ## Input: Wave grid

# %%
wave_854 = wave_854 - 0.1

f = open(file_wave, 'w')
f.write('IMPORTANT: a) All items must be separated by commas.\n') 
f.write('           b) The first six characters of the last line\n')
f.write('              in the header (if any) must contain the symbol ---\n')
f.write(' \n')
f.write('Line and blends indices :   Initial lambda     Step       Final lambda\n')
f.write('(in this order)                  (mA)          (mA)          (mA) \n')
f.write('----------------------------------------------------------------------\n')
f.write('----------------------------------------------------------------------\n')

#for iline in range(0,len(id)):
#    if iline == 0: wvl = wave_397
#    if iline == 0: wvl = wave_630
#    if iline == 0: wvl = wave_854
#
#    f.write(id_grid[iline]+'                       :{:13.5f}'.format((np.min(wvl)-wvl_cen[int(id[iline]-1)])*1e3)+ \
#            ',{:13.5f}'.format((wvl[1]-wvl[0])*1e3) + \
#            ',{:13.5f}'.format((np.max(wvl)-wvl_cen[int(id[iline]-1)])*1e3) + '\n')

f.write('1,26,27                    :{:10.2f}'.format((np.min(wave_397)-wvl_cen[int(id[0]-1)])*1e3)+ \
        ',{:10.2f}'.format((wave_397[1]-wave_397[0])*1e3)+ \
        ',{:10.2f}'.format((np.max(wave_397)-wvl_cen[int(id[0]-1)])*1e3) + '\n')

f.write('23,24                   :{:10.2f}'.format((np.min(wave_630)-wvl_cen[int(id[1]-1)])*1e3)+ \
        ',{:10.2f}'.format((wave_630[1]-wave_630[0])*1e3)+ \
        ',{:10.2f}'.format((np.max(wave_630)-wvl_cen[int(id[1]-1)])*1e3) + '\n')

f.write('4                       :{:10.2f}'.format((np.min(wave_854)-wvl_cen[int(id[2]-1)])*1e3)+ \
        ',{:10.2f}'.format((wave_854[1]-wave_854[0])*1e3)+ \
        ',{:10.2f}'.format((np.max(wave_854)-wvl_cen[int(id[2]-1)])*1e3) + '\n')

f.close()

# %% [markdown]
# ## Input: The control (*.dtrol) file

# %%
f = open(file_ctrl, 'w')
f.write('Number of cycles          (*): {:1.0f}'.format(ncycle)+'             !0=synthesis \n') 
f.write('Observed profiles         (*): '+file_obs.split(dir0)[1]+' \n')
#f.write('Stray light file             : '+file_stray.split(dir0)[1]+'  !none=no stray light contam \n')
f.write('Stray light file             :   !none=no stray light contam \n')
f.write('PSF file                     :                   !none=no convolution with PSF \n')
f.write('Wavelength grid file      (s): '+file_wave.split(dir0)[1]+'  !none=automatic selection \n')
f.write('Atomic parameters file       : '+file_lines.split(dir0)[1]+'  !none=default lines file \n')
f.write('Abundances file              : '+file_abund.split(dir0)[1]+'     !none=default abundances file \n')
f.write('Initial guess model 1     (*): '+file_atmos.split(dir0)[1]+' \n')
f.write('Initial guess model 2        : \n')
f.write('Coordinates file             : '+file_pos.split(dir0)[1]+'    !X/Rsun, Y/Rsun, Vx=1.95d5 \n')
f.write('Weight for Stokes I          : 1                 !default=1, 0=not inverted \n')
f.write('Weight for Stokes Q          : 10                !default=1, 0=not inverted \n')
f.write('Weight for Stokes U          : 10                !default=1, 0=not inverted \n')
f.write('Weight for Stokes V          : 10                 !default=1, 0=not inverted \n')
f.write('AUTOMATIC SELECT. OF NODES?  : 0,0,0,0,0,1       !default=0=no, 1=yes \n')
#f.write('Nodes for temperature 1      : 2,5,7,9,11,13,* \n')
f.write('Nodes for temperature 1      : 48,5,7,9,11,13,* \n')
f.write('Nodes for electr. press. 1   : \n')
#f.write('Nodes for microturb. 1       : 2,5,7,7,7,9,11,* \n')
f.write('Nodes for microturb. 1       : 48,5,7,9,9,11,* \n')
#f.write('Nodes for magnetic field 1   : 1,2,5,2 \n')
f.write('Nodes for magnetic field 1   : 2,48,5,2 \n')
f.write('Nodes for LOS velocity 1     : 2,48,5,4 \n')
f.write('Nodes for gamma 1            : 2,2,2,1 \n')
f.write('Nodes for phi 1              : 2,2,2,1 \n')
f.write('Invert macroturbulence 1?    : 1                 !0 or blank=no, 1=yes \n')
f.write('Nodes for temperature 2      : \n')
f.write('Nodes for electr. press. 2   : \n')
f.write('Nodes for microturb. 2       : \n')
f.write('Nodes for magnetic field 2   : \n')
f.write('Nodes for LOS velocity 2     : \n')
f.write('Nodes for gamma 2            : \n')
f.write('Nodes for phi 2              : \n')
f.write('Invert macroturbulence 2?    :                   !0 or blank=no, 1=yes \n')
f.write('Invert filling factor?       :                   !0 or blank=no, 1=yes \n')
f.write('Invert stray light factor?   :                   !0 or blank=no, 1=yes \n')
f.write('Estimated S/N for I          : 1000             !default=1000 \n')
f.write('Continuum contrast           :                   !default=not used \n')
f.write('Tolerance for SVD            :                   !default=1.e-4 \n')
f.write('Initial diagonal element     :                   !default=1.e-3 \n')
f.write('Splines/Linear Interpolation :                   !0 or blank=splines, 1=linear \n')
f.write('Gas pressure at surface 1    :                   !0 or blank=Pe boundary cond. \n')
f.write('Gas pressure at surface 2    :                   !0 or blank=Pe boundary cond. \n')
f.write('NLTE thresh. (0=NLTE,>10 LTE): 0.01              !10 (LTE)=default \n')
f.write('Number of rays               : 3                 !0 or blank=3 \n')
f.write('Integration method           : 2                 !0=herm_int, 1=herm, 2=bzr3 \n')
f.write('Final evaluation of profile  : 1,1,1,1,1 \n')
f.write('RH models mass (m) or tau(t) : t                 !default=m \n')
f.close()

# %% [markdown]
# ## Input: RH control file

# %%
print('edit '+dir0+'keyword.input')
# Out:
# edit /home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/keyword.input

# %% [markdown]
# ## Input: Atom files

# %%
print('edit '+dir0+'input/atoms.input')
# Out:
# edit /home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/input/atoms.input

# %% [markdown]
# ## Input: Molecules files

# %% [markdown]
# ## Input: Atom model

# %% [markdown]
# ## Input: Profiles

# %%
# calibrate stray light
# mag and offset are estimated in stray_01.py


for iline in range(0,3):
    if iline == 0:
#        mag = 0.25
#        offset = 0.018  #16
        stki = np.copy(stki_397)
        stkq = np.copy(stkq_397)
        stku = np.copy(stku_397)
        stkv = np.copy(stkv_397)
    if iline == 1:
#        mag = 1.0
#        offset = 0.0  #16
        stki = np.copy(stki_630)
        stkq = np.copy(stkq_630)
        stku = np.copy(stku_630)
        stkv = np.copy(stkv_630)
    if iline == 2:
#        mag = 1.5
#        offset = 0.4  #16
        stki = np.copy(stki_854)
        stkq = np.copy(stkq_854)
        stku = np.copy(stku_854)
        stkv = np.copy(stkv_854)

    qi = np.copy(stkq/stki)
    ui = np.copy(stku/stki)
    vi = np.copy(stkv/stki)

    stki_1 = np.copy(stki*mag[iline] - offset[iline])
    stkq_1 = np.copy(qi*stki_1)
    stku_1 = np.copy(ui*stki_1)
    stkv_1 = np.copy(vi*stki_1)

    if iline == 0:
        stki_397 = np.copy(stki_1)
        stkq_397 = np.copy(stkq_1)
        stku_397 = np.copy(stku_1)
        stkv_397 = np.copy(stkv_1)
    if iline == 1:
        stki_630 = np.copy(stki_1)
        stkq_630 = np.copy(stkq_1)
        stku_630 = np.copy(stku_1)
        stkv_630 = np.copy(stkv_1)
    if iline == 2:
        stki_854 = np.copy(stki_1)
        stkq_854 = np.copy(stkq_1)
        stku_854 = np.copy(stku_1)
        stkv_854 = np.copy(stkv_1)

# %%
index   = np.concatenate((np.ones(len(wave_397))*id[0], np.ones(len(wave_630))*id[1], np.ones(len(wave_854))*id[2]))
wave    = np.concatenate((wave_397-wvl_cen[int(id[0]-1)], wave_630-wvl_cen[int(id[1]-1)], wave_854-wvl_cen[int(id[2]-1)])) * 1e3
StokesI = np.concatenate((stki_397,stki_630,stki_854))
StokesQ = np.concatenate((stkq_397,stkq_630,stkq_854))
StokesU = np.concatenate((stku_397,stku_630,stku_854))
StokesV = np.concatenate((stkv_397,stkv_630,stkv_854))

array = np.transpose([index,wave,StokesI,StokesQ,StokesU,StokesV])
print('New profiles array=',array.shape)
writeprof(array,file_obs)

shutil.copyfile(file_obs, file_obs0)
# Out:
# New profiles array= (1280, 6)
# '/home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/input/profiles0.per'

# %% [markdown]
# ## Input: Weight file

# %%
profiles = readprof(file_obs)

profiles[:,2] = profiles[:,2]*0. #+1.
profiles[:,3] = profiles[:,3]*0. #+1.
profiles[:,4] = profiles[:,4]*0. #+1.
profiles[:,5] = profiles[:,5]*0. #+1.

for i in range(0,23):

    # == 854 nm
    if i == 19:
        x1 = 1200
        x2 = len(wave_397)+len(wave_630)+len(wave_854)
        wgti= 1.
        wgtp= 1.
    if i == 18:      # Ca II 854 nm core
        x1 = 1050
        x2 = 1200
        wgti= 2.0
        wgtp= 3.0
    if i == 17:
        x1 = len(wave_397)+len(wave_630)+1
        x2 = 1050
        wgti= 1.
        wgtp= 1.
    if i == 21:      # Ca II 854 nm large V component, cannot fit even with wight 100
        x1 = 1130
        x2 = 1170
        wgti= 2.0
        wgtp= 3.0


    # == Fe I 630 nm
    if i == 15:
        x1 = 900
        x2 = 950
        wgti= 0.
        wgtp= 0.
    if i == 14:
        x1 = 870
        x2 = 900
        wgti= 1.
        wgtp= 1.
    if i == 13:
        x1 = 860
        x2 = 870
        wgti= 0.
        wgtp= 0.
    if i == 12:   # Fe I 6302.5
        x1 = 810
        x2 = 860
        wgti= 2.
        wgtp= 2.
    if i == 11:
        x1 = 790
        x2 = 810
        wgti= 0.
        wgtp= 0.
    if i == 10:    # Fe I 6301.5
        x1 = 715
        x2 = 800
        wgti= 2.
        wgtp= 2.
    if i == 9:
        x1 = len(wave_397)+10
        x2 = 715
        wgti= 0.
        wgtp= 0.
    if i == 8:
        x1 = len(wave_397)+1
        x2 = len(wave_397)+10
        wgti= 1.
        wgtp= 1.
    #== 397 nm ==
    if i == 0:
        x1 = 450
        x2 = len(wave_397)
        wgti= 1.
        wgtp= 1.
    if i == 1:
        x1   = 400
        x2   = 450
        wgti = 0.
        wgtp = 0.
    if i == 2:
        x1 = 200
        x2 = 400
        wgti= 1.
        wgtp= 1.
    if i == 16:       # Ca II H core
        x1 = 270
        x2 = 350
        wgti= 2.0
        wgtp= 2.
    if i == 3:
        x1 = 160
        x2 = 200
        wgti= 0.
        wgtp= 0.
    if i == 4:
        x1 = 120
        x2 = 160
        wgti= 1.
        wgtp= 1.
    if i == 5:
        x1 = 40
        x2 = 120
        wgti= 0.
        wgtp= 0.
    if i == 6:
        x1 = 20
        x2 = 40
        wgti= 1.
        wgtp= 1.
    if i == 7:
        x1 = 0
        x2 = 20
        wgti= 0.
        wgtp= 0.
    if i == 20:       # Ca II H core
        x1 = 305
        x2 = 325
        wgti= 2.0
        wgtp= 2.
    if i == 22:       # Fe I & Ni I
        x1 = 550
        x2 = 590
        wgti= 1.0
        wgtp= 1.0


        

    profiles[x1:x2,2] = profiles[x1:x2,2]*0.+wgti
    profiles[x1:x2,3] = profiles[x1:x2,3]*0.+wgtp
    profiles[x1:x2,4] = profiles[x1:x2,4]*0.+wgtp
    profiles[x1:x2,5] = profiles[x1:x2,5]*0.+wgtp

outfile = (file_obs.split('.'))[0]+'.wht'
writeprof(profiles,outfile)

# %%
profiles = readprof(file_obs)
weight    = readprof((file_obs.split('.'))[0]+'.wht')

fig, ax = plt.subplots(nrows=2, ncols=1, figsize = (8,8), dpi=80)

ax = ax.flatten()

ax[0].plot(profiles[:,2], color='black', linewidth=3, linestyle='-', alpha=1, label='YES')
wgh = np.copy(weight[:,2])
pos = (np.where(weight[:,2] > 0))[0]
ax[0].plot(pos,profiles[pos,2], marker = '.', color='red', linewidth=3, linestyle=' ', alpha=1, label='YES')
ax[0].plot(wgh/(max(wgh)), color='red', linewidth=3, linestyle='-', alpha=1, label='YES')


ax[1].plot(profiles[:,5], color='black', linewidth=3, linestyle='-', alpha=1, label='YES')
wgh = np.copy(weight[:,5])
pos = (np.where(weight[:,5] > 0))[0]
ax[1].plot(pos,profiles[pos,5], marker = '.', color='red', linewidth=3, linestyle=' ', alpha=1, label='YES')
ax[1].plot(wgh/(max(wgh))*0.01, color='red', linewidth=3, linestyle='-', alpha=1, label='YES')




fig.tight_layout()

# %% [markdown]
# ## Input: Stray light

# %%
profiles = readprof(file_obs)

profiles[:,2] = profiles[:,2]*0.+100.
profiles[:,3] = profiles[:,3]*0.+100.
profiles[:,4] = profiles[:,4]*0.+100.
profiles[:,5] = profiles[:,5]*0.+100.

writeprof(profiles,file_stray)

# %% [markdown]
# ## Input: pos.coor

# %%
f = open(file_pos, 'w')
f.write('{:.0f}'.format(hxy[0])+',{:.0f}'.format(hxy[1])+',0,0\n') 
f.close()

# %% [markdown]
# # Run DeSIRe

# %%
os.chdir(dir0)
cmd = dir0 + '../../bin/desire '+file_ctrl
os.system(cmd)
# Out:
#
#   __________________________________________________________
#  |                                                          |
#  |            DeSIRe version 4.12  (12/Dec/2022)            |
#  |__________________________________________________________|
#
#  Number of cycles          (*):  2.000000
#  Observed profiles         (*): input/profiles.per
#  Stray light file             :
#  PSF file                     :
#  Wavelength grid file      (s): input/wave.grid
#  Atomic parameters file       : input/LINES_NLTE
#  Abundances file              : input/ASPLUND
#  Initial guess model 1     (*): input/atmos.mod
#  Initial guess model 2        :
#  Coordinates file             : input/pos.coor
#  Weight for Stokes I          :  1.00E+00
#  Weight for Stokes Q          :  1.00E+01
#  Weight for Stokes U          :  1.00E+01
#  Weight for Stokes V          :  1.00E+01
#  AUTOMATIC SELECT. OF NODES?  :           0
#  Nodes for temperature 1      :          48
# ...

# %% [markdown]
# # Results

# %% [markdown]
# ## Results: Profiles

# %% [markdown]
# ### Results: Profiles: Read

# %%
if ncycle == 0:
    profiles = readprof(file_obs0)
    outprofiles = readprof(file_obs)
else:
    profiles = readprof(file_obs)
    outprofiles = readprof(file_outpro)




print('------------------------------------------')
print('Profiles array = ',profiles.shape)
print('')

index   = profiles[:,0]
wave    = profiles[:,1]
StokesI = profiles[:,2]
StokesQ = profiles[:,3]
StokesU = profiles[:,4]
StokesV = profiles[:,5]

index397 = np.array(np.where(index == 1)).reshape(-1)
index630 = np.array(np.where(index == 23)).reshape(-1)
index854 = np.array(np.where(index == 4)).reshape(-1)

wave_397 = wave[index397]*1e-3 + wvl_cen[int(id[0]-1)]
stki_397 = StokesI[index397]
stkq_397 = StokesQ[index397]
stku_397 = StokesU[index397]
stkv_397 = StokesV[index397]

wave_630    = wave[index630]*1e-3 + wvl_cen[int(id[1]-1)]
stki_630 = StokesI[index630]
stkq_630 = StokesQ[index630]
stku_630 = StokesU[index630]
stkv_630 = StokesV[index630]

wave_854    = wave[index854]*1e-3 + wvl_cen[int(id[2]-1)]
stki_854 = StokesI[index854]
stkq_854 = StokesQ[index854]
stku_854 = StokesU[index854]
stkv_854 = StokesV[index854]

# --------

index   = outprofiles[:,0]
wave    = outprofiles[:,1]
StokesI = outprofiles[:,2]
StokesQ = outprofiles[:,3]
StokesU = outprofiles[:,4]
StokesV = outprofiles[:,5]

index397 = np.array(np.where(index == 1)).reshape(-1)
index630 = np.array(np.where(index == 23)).reshape(-1)
index854 = np.array(np.where(index == 4)).reshape(-1)

outwave_397 = wave[index397]*1e-3 + wvl_cen[int(id[0]-1)]
outstki_397 = StokesI[index397]
outstkq_397 = StokesQ[index397]
outstku_397 = StokesU[index397]
outstkv_397 = StokesV[index397]

outwave_630    = wave[index630]*1e-3 + wvl_cen[int(id[1]-1)]
outstki_630 = StokesI[index630]
outstkq_630 = StokesQ[index630]
outstku_630 = StokesU[index630]
outstkv_630 = StokesV[index630]

outwave_854    = wave[index854]*1e-3 + wvl_cen[int(id[2]-1)]
outstki_854 = StokesI[index854]
outstkq_854 = StokesQ[index854]
outstku_854 = StokesU[index854]
outstkv_854 = StokesV[index854]
# Out:
# ------------------------------------------
# Profiles array =  (1280, 6)

# %% [markdown]
# ### Results: Profiles: Plot

# %%
print('Inversion results')
fig, ax = plt.subplots(nrows=12, ncols=1, figsize = (8,20), dpi=80)
#fig.suptitle('Observed profile', fontsize=16)
ax = ax.flatten()
for iline in range(0,3):
    if iline == 0:
        wavename = 'Ca II H & H epsilon'
        wave = wave_397
        stki = stki_397
        stkq = stkq_397
        stku = stku_397
        stkv = stkv_397

        owave = outwave_397
        ostki = outstki_397
        ostkq = outstkq_397
        ostku = outstku_397
        ostkv = outstkv_397
    if iline == 1:
        wavename = 'Fe I 630 nm'
        wave = wave_630
        stki = stki_630
        stkq = stkq_630
        stku = stku_630
        stkv = stkv_630

        owave = outwave_630
        ostki = outstki_630
        ostkq = outstkq_630
        ostku = outstku_630
        ostkv = outstkv_630
    if iline == 2:
        wavename = 'Ca II 854 nm'
        wave = wave_854
        stki = stki_854
        stkq = stkq_854
        stku = stku_854
        stkv = stkv_854

        owave = outwave_854
        ostki = outstki_854
        ostkq = outstkq_854
        ostku = outstku_854
        ostkv = outstkv_854

    for ipol in range(0,4):
        if ipol == 0:
            title = wavename+', Stokes I'
            stk = stki
            ostk = ostki
        if ipol == 1:
            title = wavename+', Stokes Q'
            stk = stkq
            ostk = ostkq
        if ipol == 2:
            title = wavename+', Stokes U'
            stk = stku
            ostk = ostku
        if ipol == 3:
            title = wavename+', Stokes V'
            stk = stkv
            ostk = ostkv

            
        i = iline*4 + ipol
        ax[i].plot(wave,stk, marker='+', color='black', linewidth=3, linestyle=' ', alpha=1, label='YES')
        ax[i].plot(owave,ostk, color='red', linewidth=3, linestyle='-', alpha=1, label='YES')

        ax[i].set_title(title)

fig.tight_layout()
# Out:
# Inversion results

# %%
print('Inversion results')
fig, ax = plt.subplots(nrows=12, ncols=1, figsize = (8,20), dpi=80)
#fig.suptitle('Observed profile', fontsize=16)
ax = ax.flatten()
for iline in range(0,3):
    if iline == 0:
        wavename = 'Ca II H & H epsilon'
        wave = wave_397
        stki = stki_397
        stkq = stkq_397
        stku = stku_397
        stkv = stkv_397

        owave = outwave_397
        ostki = outstki_397
        ostkq = outstkq_397
        ostku = outstku_397
        ostkv = outstkv_397
    if iline == 1:
        wavename = 'Fe I 630 nm'
        wave = wave_630
        stki = stki_630
        stkq = stkq_630
        stku = stku_630
        stkv = stkv_630

        owave = outwave_630
        ostki = outstki_630
        ostkq = outstkq_630
        ostku = outstku_630
        ostkv = outstkv_630
    if iline == 2:
        wavename = 'Ca II 854 nm'
        wave = wave_854
        stki = stki_854
        stkq = stkq_854
        stku = stku_854
        stkv = stkv_854

        owave = outwave_854
        ostki = outstki_854
        ostkq = outstkq_854
        ostku = outstku_854
        ostkv = outstkv_854

    for ipol in range(0,4):
        if ipol == 0:
            title = wavename+', Stokes I'
            stk = stki
            ostk = ostki
        if ipol == 1:
            title = wavename+', Stokes Q'
            stk = stkq
            ostk = ostkq
        if ipol == 2:
            title = wavename+', Stokes U'
            stk = stku
            ostk = ostku
        if ipol == 3:
            title = wavename+', Stokes V'
            stk = stkv
            ostk = ostkv
            
            nw = len(stki)
            dstki = stki[2:] - stki[0:nw-2]
            dwave = wave[1:nw-1]

            
        i = iline*4 + ipol
        ax[i].plot(wave,stk, marker='+', color='black', linewidth=3, linestyle=' ', alpha=1, label='YES')
        ax[i].plot(owave,ostk, color='red', linewidth=3, linestyle='-', alpha=1, label='YES')
        if ipol == 3:
            ax[i].plot(dwave,dstki/np.max(abs(dstki))*np.max(abs(stk)), color='blue', linewidth=3, linestyle='--', alpha=1, label='YES')
        
        ax[i].set_title(title)

fig.tight_layout()
# Out:
# Inversion results

# %% [markdown]
# ## Results: Atmosphere

# %%
atm0,atm1 = readmod(file_outmod)

# %%
print('Macroturbulence [km/s]: ', atm0[0])
print('Filling factor        : ', atm0[1])
print('Stray light           : ', atm0[2])
# Out:
# Macroturbulence [km/s]:  1.82554138
# Filling factor        :  1.0
# Stray light           :  0.0

# %%
fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,1])
axs.set(ylabel='Temperature [K]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,2])
axs.set(ylabel='Electron Pressure [dyn/cm2]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,3]*1e-5)
axs.set(ylabel='Microturbulence [km/s]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,4])
axs.set(ylabel='Magnetic field strength [G]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,5]*1e-5)
axs.set(ylabel='LOS velocity [km/s]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,6])
axs.set(ylabel='Magnetic field inclination [degrees]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,7])
axs.set(ylabel='Magnetic field azimuth [degrees]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,8])
axs.set(ylabel='Geometrical height [km]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,9])
axs.set(ylabel='Gas pressure [dyn/cm2]',xlabel='log '+r'$\tau_{500}$')
plt.show()

fig, axs = plt.subplots()
axs.plot(atm1[:,0],atm1[:,10])
axs.set(ylabel='Gas density [cm-3]',xlabel='log '+r'$\tau_{500}$')
plt.show()

# fig.savefig('Temperature_HSRA.png',dpi=300, bbox_inches = 'tight', pad_inches = 0.1)
# fig.savefig('Temperature_HSRA.eps',dpi=300, bbox_inches = 'tight', pad_inches = 0.01)
# sys.exit()

# %% [markdown]
# # Responce function

# %%
f = open(file_rfctrl, 'w')
f.write('Number of cycles          (*): -1             !0=synthesis \n') 
f.write('Observed profiles         (*): '+file_obs.split(dir0)[1]+' \n')
f.write('Stray light file             :                   !none=no stray light contam \n')
f.write('PSF file                     :                   !none=no convolution with PSF \n')
f.write('Wavelength grid file      (s): '+file_wave.split(dir0)[1]+'  !none=automatic selection \n')
f.write('Atomic parameters file       : '+file_lines.split(dir0)[1]+'  !none=default lines file \n')
f.write('Abundances file              : '+file_abund.split(dir0)[1]+'     !none=default abundances file \n')
f.write('Initial guess model 1     (*): '+file_outmod.split(dir0)[1]+' \n')
f.write('Initial guess model 2        : \n')
f.write('Coordinates file             : '+file_pos.split(dir0)[1]+'    !X/Rsun, Y/Rsun, Vx=1.95d5 \n')
f.write('Weight for Stokes I          : 1                 !default=1, 0=not inverted \n')
f.write('Weight for Stokes Q          : 1                 !default=1, 0=not inverted \n')
f.write('Weight for Stokes U          : 1                 !default=1, 0=not inverted \n')
f.write('Weight for Stokes V          : 1                 !default=1, 0=not inverted \n')
f.write('AUTOMATIC SELECT. OF NODES?  : 0,0,0,0,0,1       !default=0=no, 1=yes \n')
f.write('Nodes for temperature 1      : 1 \n')
f.write('Nodes for electr. press. 1   : 0 \n')
f.write('Nodes for microturb. 1       : 1 \n')
f.write('Nodes for magnetic field 1   : 1 \n')
f.write('Nodes for LOS velocity 1     : 1 \n')
f.write('Nodes for gamma 1            : 1 \n')
f.write('Nodes for phi 1              : 1 \n')
f.write('Invert macroturbulence 1?    : 0                 !0 or blank=no, 1=yes \n')
f.write('Nodes for temperature 2      : \n')
f.write('Nodes for electr. press. 2   : \n')
f.write('Nodes for microturb. 2       : \n')
f.write('Nodes for magnetic field 2   : \n')
f.write('Nodes for LOS velocity 2     : \n')
f.write('Nodes for gamma 2            : \n')
f.write('Nodes for phi 2              : \n')
f.write('Invert macroturbulence 2?    :                   !0 or blank=no, 1=yes \n')
f.write('Invert filling factor?       :                   !0 or blank=no, 1=yes \n')
f.write('Invert stray light factor?   :                   !0 or blank=no, 1=yes \n')
f.write('Estimated S/N for I          : 1000              !default=1000 \n')
f.write('Continuum contrast           :                   !default=not used \n')
f.write('Tolerance for SVD            :                   !default=1.e-4 \n')
f.write('Initial diagonal element     :                   !default=1.e-3 \n')
f.write('Splines/Linear Interpolation :                   !0 or blank=splines, 1=linear \n')
f.write('Gas pressure at surface 1    :                   !0 or blank=Pe boundary cond. \n')
f.write('Gas pressure at surface 2    :                   !0 or blank=Pe boundary cond. \n')
f.write('NLTE thresh. (0=NLTE,>10 LTE): 0.01              !10 (LTE)=default \n')
f.write('Number of rays               : 3                 !0 or blank=3 \n')
f.write('Integration method           : 2                 !0=herm_int, 1=herm, 2=bzr3 \n')
f.write('Final evaluation of profile  : 1,1,1,1,1 \n')
f.write('RH models mass (m) or tau(t) : t                 !default=m \n')
f.close()

# %%
os.chdir(dir0)
cmd = dir0 + '../../bin/desire '+file_rfctrl
os.system(cmd)
# Out:
#
#   __________________________________________________________
#  |                                                          |
#  |            DeSIRe version 4.12  (12/Dec/2022)            |
#  |__________________________________________________________|
#
#  Number of cycles          (*): -1.00E+00
#  Observed profiles         (*): input/profiles.per
#  Stray light file             :
#  PSF file                     :
#  Wavelength grid file      (s): input/wave.grid
#  Atomic parameters file       : input/LINES_NLTE
#  Abundances file              : input/ASPLUND
#  Initial guess model 1     (*): input/atmos_2.mod
#  Initial guess model 2        :
#  Coordinates file             : input/pos.coor
#  Weight for Stokes I          :  1.00E+00
#  Weight for Stokes Q          :  1.00E+00
#  Weight for Stokes U          :  1.00E+00
#  Weight for Stokes V          :  1.00E+00
#  AUTOMATIC SELECT. OF NODES?  :           0
#  Nodes for temperature 1      :           1
# ...

# %%
name = file_outmod.split('.')[0]+'.rt'
print(name)
sys.exit()
SiRF, SqRF, SuRF, SvRF = readrf(name)
print(SiRF.shape)
# Out:
# /home/tanan/lib/desire/Source_code/desire20221219/run/tanan_dkist_ocp01_feb_04/input/atmos_2.rt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /opt/anaconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
